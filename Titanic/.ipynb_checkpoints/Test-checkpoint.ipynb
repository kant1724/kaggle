# %%
import pandas as pd

train_df = pd.read_csv('./train.csv')
test_df = pd.read_csv('./test.csv')

# %%
train_df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
from sklearn.preprocessing import LabelEncoder

for col in list(train_df):
    if col in ['Name', 'Cabin', 'Ticket']:
        continue
    if train_df[col].dtype == 'O':
        train_df[col] = train_df[col].fillna('unseen_before_label')
        test_df[col] = test_df[col].fillna('unseen_before_label')
        train_df[col] = train_df[col].astype(str)
        test_df[col] = test_df[col].astype(str)
        le = LabelEncoder()
        le.fit(train_df[col])
        train_df[col] = le.transform(train_df[col])
        test_df[col] = le.transform(test_df[col])

# %%
test_df.head()
# Out:
#    PassengerId  Pclass                                          Name  Sex  \
# 0          892       3                              Kelly, Mr. James    1
# 1          893       3              Wilkes, Mrs. James (Ellen Needs)    0
# 2          894       2                     Myles, Mr. Thomas Francis    1
# 3          895       3                              Wirz, Mr. Albert    1
# 4          896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)    0
#
#     Age  SibSp  Parch   Ticket     Fare Cabin  Embarked
# 0  34.5      0      0   330911   7.8292   NaN         1
# 1  47.0      1      0   363272   7.0000   NaN         2
# 2  62.0      0      0   240276   9.6875   NaN         1
# 3  27.0      0      0   315154   8.6625   NaN         2
# 4  22.0      1      1  3101298  12.2875   NaN         2

# %%
import lightgbm as lgb
import seaborn as sns
import numpy as np
from lightgbm import LGBMClassifier
from sklearn.model_selection import KFold, StratifiedKFold

folds = StratifiedKFold(n_splits=2, shuffle=True, random_state=1001)
sub_preds = np.zeros(test_df.shape[0])
feats = [f for f in train_df.columns if f not in ['Survived', 'PassengerId', 'Name', 'Cabin', 'Ticket']]

for n_fold, (train_idx, valid_idx) in enumerate(folds.split(train_df[feats], train_df['Survived'])):
    train_x, train_y = train_df[feats].iloc[train_idx], train_df['Survived'].iloc[train_idx]
    valid_x, valid_y = train_df[feats].iloc[valid_idx], train_df['Survived'].iloc[valid_idx]
    clf = LGBMClassifier(
                objective='binary',
                boosting_type='gbdt',
                metric='auc',
                n_jobs=-1,
                num_leaves=910,
                max_depth=-1,
                tree_learner='serial',
                colsample_bytree=0.7312219438641832,
                subsample_freq=4,
                subsample=0.8754761947091015,
                n_estimators=800,
                max_bin=255,
                verbose=-1,
                seed=42,
                learning_rate=0.07928065415431466
                )


    clf.fit(train_x, train_y, eval_set = [(train_x, train_y), (valid_x, valid_y)], early_stopping_rounds=100)
    
    sub_preds += clf.predict_proba(test_df[feats], num_iteration=clf.best_iteration_)[:, 1] / folds.n_splits
    
model_json = clf.booster_.dump_model()
# Out:
# [1]	training's auc: 0.87588	valid_1's auc: 0.799468
# Training until validation scores don't improve for 100 rounds.
# [2]	training's auc: 0.879402	valid_1's auc: 0.800447
# [3]	training's auc: 0.892667	valid_1's auc: 0.832982
# [4]	training's auc: 0.902602	valid_1's auc: 0.845901
# [5]	training's auc: 0.910573	valid_1's auc: 0.847305
# [6]	training's auc: 0.912889	valid_1's auc: 0.845508
# [7]	training's auc: 0.90862	valid_1's auc: 0.852313
# [8]	training's auc: 0.904971	valid_1's auc: 0.853546
# [9]	training's auc: 0.909122	valid_1's auc: 0.857586
# [10]	training's auc: 0.912345	valid_1's auc: 0.857023
# [11]	training's auc: 0.914031	valid_1's auc: 0.859011
# [12]	training's auc: 0.916784	valid_1's auc: 0.861627
# [13]	training's auc: 0.917446	valid_1's auc: 0.860723
# [14]	training's auc: 0.916592	valid_1's auc: 0.860766
# [15]	training's auc: 0.916037	valid_1's auc: 0.860191
# [16]	training's auc: 0.918598	valid_1's auc: 0.859979
# [17]	training's auc: 0.918833	valid_1's auc: 0.860213

#    'tree_structure': {'split_index': 0,
#     'split_feature': 1,
#     'split_gain': 103.57099914550781,
#     'threshold': 1.0000000180025095e-35,
#     'decision_type': '<=',
#     'default_left': True,
#     'missing_type': 'None',
#     'internal_value': 0,
#     'internal_count': 390,
#     'left_child': {'split_index': 1,
#      'split_feature': 5,
#      'split_gain': 14.633899688720703,
#      'threshold': 25.5271,
#      'decision_type': '<=',
#      'default_left': True,
#      'missing_type': 'None',
#      'internal_value': 1.4166400000000001,
#      'internal_count': 142,
#      'left_child': {'split_index': 6,
#       'split_feature': 2,
#       'split_gain': 2.9177799224853516,
#       'threshold': 36.25000000000001,
#       'decision_type': '<=',
#       'default_left': False,
#       'missing_type': 'NaN',
#       'internal_value': 0.818569,
#       'internal_count': 78,
#       'left_child': {'split_index': 7,
#        'split_feature': 5,
#        'split_gain': 2.7208399772644043,
#        'threshold': 14.427100000000001,
#        'decision_type': '<=',
#        'default_left': True,
#        'missing_type': 'None',
#        'internal_value': 1.09177,
#        'internal_count': 53,
#        'left_child': {'leaf_index': 0,
#         'leaf_value': -0.35978992074580907,
#         'leaf_count': 33},
#        'right_child': {'leaf_index': 8,
#         'leaf_value': -0.4360075532097269,
#         'leaf_count': 20}},
#       'right_child': {'leaf_index': 7,
#        'leaf_value': -0.4561290081802012,
#        'leaf_count': 25}},
#      'right_child': {'split_index': 8,
#       'split_feature': 2,
#       'split_gain': 2.4334499835968018,
#       'threshold': 15.500000000000002,
#       'decision_type': '<=',
#       'default_left': True,
#       'missing_type': 'NaN',
#       'internal_value': 2.14553,
#       'internal_count': 64,
#       'left_child': {'leaf_index': 2,
#        'leaf_value': -0.3521681574994172,
#        'leaf_count': 20},
#       'right_child': {'split_index': 13,
#        'split_feature': 5,
#        'split_gain': 0.46145498752593994,
#        'threshold': 56.71250000000001,
#        'decision_type': '<=',
#        'default_left': True,
#        'missing_type': 'None',
#        'internal_value': 2.4159100000000002,
#        'internal_count': 44,
#        'left_child': {'leaf_index': 9,
#         'leaf_value': -0.3018645200732314,
#         'leaf_count': 20},
#        'right_child': {'leaf_index': 14,
#         'leaf_value': -0.2683287617891076,
#         'leaf_count': 24}}}},
#     'right_child': {'split_index': 2,
#      'split_feature': 5,
#      'split_gain': 12.99020004272461,
#      'threshold': 26.266650000000002,
#      'decision_type': '<=',
#      'default_left': True,
#      'missing_type': 'None',
#      'internal_value': -0.786051,
#      'internal_count': 248,
#      'left_child': {'split_index': 3,
#       'split_feature': 2,
#       'split_gain': 3.817739963531494,
#       'threshold': 20.500000000000004,
#       'decision_type': '<=',
#       'default_left': False,
#       'missing_type': 'NaN',
#       'internal_value': -1.0783,
#       'internal_count': 179,
#       'left_child': {'leaf_index': 1,
#        'leaf_value': -0.4969816591808612,
#        'leaf_count': 22},
#       'right_child': {'split_index': 9,
#        'split_feature': 6,
#        'split_gain': 2.126159906387329,
#        'threshold': 1.0000000180025095e-35,
#        'decision_type': '<=',
#        'default_left': True,
#        'missing_type': 'None',
#        'internal_value': -1.19073,
#        'internal_count': 157,
#        'left_child': {'leaf_index': 4,
#         'leaf_value': -0.5198469489200366,
#         'leaf_count': 20},
#        'right_child': {'split_index': 10,
#         'split_feature': 2,
#         'split_gain': 1.561769962310791,
#         'threshold': 23.500000000000004,
#         'decision_type': '<=',
#         'default_left': True,
#         'missing_type': 'NaN',
#         'internal_value': -1.2821799999999999,
#         'internal_count': 137,
#         'left_child': {'split_index': 14,
#          'split_feature': 5,
#          'split_gain': 0.1258929967880249,
#          'threshold': 7.781250000000001,
#          'decision_type': '<=',
#          'default_left': True,
#          'missing_type': 'None',
#          'internal_value': -1.5462799999999999,
#          'internal_count': 56,
#          'left_child': {'leaf_index': 10,
#           'leaf_value': -0.5877169359236205,
#           'leaf_count': 21},
#          'right_child': {'leaf_index': 15,
#           'leaf_value': -0.6036863446303462,
#           'leaf_count': 35}},
#         'right_child': {'split_index': 11,
#          'split_feature': 5,
#          'split_gain': 1.2794500589370728,
#          'threshold': 11.316650000000001,
#          'decision_type': '<=',
#          'default_left': True,
#          'missing_type': 'None',
#          'internal_value': -1.0996,
#          'internal_count': 81,
#          'left_child': {'split_index': 12,
#           'split_feature': 2,
#           'split_gain': 1.2690000534057617,
#           'threshold': 32.25000000000001,
#           'decision_type': '<=',
#           'default_left': True,
#           'missing_type': 'NaN',
#           'internal_value': -0.916817,
#           'internal_count': 54,
#           'left_child': {'leaf_index': 11,
#            'leaf_value': -0.5254362419673905,
#            'leaf_count': 30},
#           'right_child': {'leaf_index': 13,
#            'leaf_value': -0.5757398793935763,
#            'leaf_count': 24}},
#          'right_child': {'leaf_index': 12,
#           'leaf_value': -0.591265693414004,
#           'leaf_count': 27}}}}},
#      'right_child': {'split_index': 4,
#       'split_feature': 2,
#       'split_gain': 3.7243099212646484,
#       'threshold': 24.500000000000004,
#       'decision_type': '<=',
#       'default_left': False,
#       'missing_type': 'NaN',
#       'internal_value': -0.0279031,
#       'internal_count': 69,
#       'left_child': {'leaf_index': 3,
#        'leaf_value': -0.5366148280620985,
#        'leaf_count': 20},
#       'right_child': {'split_index': 5,
#        'split_feature': 2,
#        'split_gain': 7.878170013427734,
#        'threshold': 39.50000000000001,
#        'decision_type': '<=',
#        'default_left': True,
#        'missing_type': 'NaN',
#        'internal_value': 0.277368,
#        'internal_count': 49,
#        'left_child': {'leaf_index': 5,
#         'leaf_value': -0.38905749161195347,
#         'leaf_count': 25},
#        'right_child': {'leaf_index': 6,
#         'leaf_value': -0.5198469489200366,
#         'leaf_count': 24}}}}}},
#   {'tree_index': 1,
#    'num_leaves': 13,
#    'num_cat': 0,
#    'shrinkage': 0.0792807,
#    'tree_structure': {'split_index': 0,
#     'split_feature': 1,
#     'split_gain': 86.97989654541016,
#     'threshold': 1.0000000180025095e-35,
#     'decision_type': '<=',
#     'default_left': True,
#     'missing_type': 'None',
#     'internal_value': 0,
#     'internal_count': 390,
#     'left_child': {'split_index': 3,
#      'split_feature': 2,
#      'split_gain': 2.7105300426483154,
#      'threshold': 18.500000000000004,
#      'decision_type': '<=',
#      'default_left': True,
#      'missing_type': 'NaN',
#      'internal_value': 1.2739500000000001,
#      'internal_count': 142,
#      'left_child': {'split_index': 7,
#       'split_feature': 6,
#       'split_gain': 1.2903599739074707,
#       'threshold': 1.5000000000000002,
#       'decision_type': '<=',
#       'default_left': True,
#       'missing_type': 'None',
#       'internal_value': 0.938828,
#       'internal_count': 59,
#       'left_child': {'leaf_index': 0,
#        'leaf_value': 0.10342614126918107,
#        'leaf_count': 24},
#       'right_child': {'leaf_index': 8,
#        'leaf_value': 0.05469165620530842,
#        'leaf_count': 35}},
#      'right_child': {'split_index': 4,
#       'split_feature': 6,
#       'split_gain': 2.6135001182556152,
#       'threshold': 1.0000000180025095e-35,
#       'decision_type': '<=',
#       'default_left': True,
#       'missing_type': 'None',
#       'internal_value': 1.5096,
#       'internal_count': 83,
#       'left_child': {'leaf_index': 4,
#        'leaf_value': 0.17015342441323064,
#        'leaf_count': 20},
#       'right_child': {'split_index': 9,
#        'split_feature': 2,
#        'split_gain': 0.5712419748306274,
#        'threshold': 27.500000000000004,
#        'decision_type': '<=',
#        'default_left': True,
#        'missing_type': 'NaN',
#        'internal_value': 1.30589,
#        'internal_count': 63,
#        'left_child': {'leaf_index': 5,
#         'leaf_value': 0.123060926605761,
#         'leaf_count': 24},
#        'right_child': {'leaf_index': 10,
#         'leaf_value': 0.09148963457289146,
#         'leaf_count': 39}}}},
#     'right_child': {'split_index': 1,
#      'split_feature': 6,
#      'split_gain': 4.615119934082031,
#      'threshold': 1.0000000180025095e-35,
#      'decision_type': '<=',
#      'default_left': True,
#      'missing_type': 'None',
#      'internal_value': -0.736504,
#      'internal_count': 248,
#      'left_child': {'leaf_index': 1,
#       'leaf_value': -0.00682698345009193,
#       'leaf_count': 39},
#      'right_child': {'split_index': 2,
#       'split_feature': 2,
#       'split_gain': 3.8726999759674072,
#       'threshold': 53.00000000000001,
#       'decision_type': '<=',
#       'default_left': False,
#       'missing_type': 'NaN',
#       'internal_value': -0.859512,
#       'internal_count': 209,
#       'left_child': {'split_index': 5,
#        'split_feature': 2,
#        'split_gain': 2.518549919128418,
#        'threshold': 17.500000000000004,
#        'decision_type': '<=',
#        'default_left': True,
#        'missing_type': 'NaN',
#        'internal_value': -0.689564,
#        'internal_count': 153,
#        'left_child': {'leaf_index': 2,
#         'leaf_value': -0.00338001683989207,
#         'leaf_count': 22},
#        'right_child': {'split_index': 6,
#         'split_feature': 2,
#         'split_gain': 4.473549842834473,
#         'threshold': 26.500000000000004,
#         'decision_type': '<=',
#         'default_left': True,
#         'missing_type': 'NaN',
#         'internal_value': -0.798849,
#         'internal_count': 131,
#         'left_child': {'split_index': 11,
#          'split_feature': 2,
#          'split_gain': 0.21160300076007843,
#          'threshold': 22.500000000000004,
#          'decision_type': '<=',
#          'default_left': True,
#          'missing_type': 'NaN',
#          'internal_value': -1.30449,
#          'internal_count': 48,
#          'left_child': {'leaf_index': 6,
#           'leaf_value': -0.11266296881291468,
#           'leaf_count': 28},
#          'right_child': {'leaf_index': 12,
#           'leaf_value': -0.0904739788456445,
#           'leaf_count': 20}},
#         'right_child': {'split_index': 8,
#          'split_feature': 2,
#          'split_gain': 0.9574170112609863,
#          'threshold': 37.50000000000001,
#          'decision_type': '<=',
#          'default_left': True,
#          'missing_type': 'NaN',
#          'internal_value': -0.508537,
#          'internal_count': 83,
#          'left_child': {'split_index': 10,
#           'split_feature': 2,
#           'split_gain': 0.5012419819831848,
#           'threshold': 31.500000000000004,
#           'decision_type': '<=',
#           'default_left': False,
#           'missing_type': 'NaN',
#           'internal_value': -0.329171,
#           'internal_count': 50,
#           'left_child': {'leaf_index': 7,
#            'leaf_value': -0.0431398095975912,
#            'leaf_count': 24},
#           'right_child': {'leaf_index': 11,
#            'leaf_value': -0.01033654492576229,
#            'leaf_count': 26}},
#          'right_child': {'leaf_index': 9,
#           'leaf_value': -0.062176133079931604,
#           'leaf_count': 33}}}},
#       'right_child': {'leaf_index': 3,
#        'leaf_value': -0.10538352994183513,
#        'leaf_count': 56}}}}},
#   {'tree_index': 2,
#    'num_leaves': 16,
#    'num_cat': 0,
#    'shrinkage': 0.0792807,
#    'tree_structure': {'split_index': 0,
#     'split_feature': 1,
#     'split_gain': 73.48789978027344,
#     'threshold': 1.0000000180025095e-35,
#     'decision_type': '<=',
#     'default_left': True,
#     'missing_type': 'None',
#     'internal_value': 0,
#     'internal_count': 390,
#     'left_child': {'split_index': 1,
#      'split_feature': 0,
#      'split_gain': 35.05699920654297,
#      'threshold': 2.5000000000000004,
#      'decision_type': '<=',
#      'default_left': True,
#      'missing_type': 'None',
#      'internal_value': 1.15483,
#      'internal_count': 142,
#      'left_child': {'split_index': 12,
#       'split_feature': 3,
#       'split_gain': 0.16702799499034882,
#       'threshold': 1.0000000180025095e-35,
#       'decision_type': '<=',
#       'default_left': True,
#       'missing_type': 'None',
#       'internal_value': 2.08397,
#       'internal_count': 76,
#       'left_child': {'split_index': 14,
#        'split_feature': 5,
#        'split_gain': 0.011439500376582146,
#        'threshold': 26.125000000000004,
#        'decision_type': '<=',
#        'default_left': True,
#        'missing_type': 'None',
#        'internal_value': 2.16025,
#        'internal_count': 46,
#        'left_child': {'leaf_index': 0,
#         'leaf_value': 0.16837757341093282,
#         'leaf_count': 20},
#        'right_child': {'leaf_index': 15,
#         'leaf_value': 0.1734606450577113,
#         'leaf_count': 26}},
#       'right_child': {'leaf_index': 13,
#        'leaf_value': 0.15595987295969196,
#        'leaf_count': 30}},
#      'right_child': {'split_index': 4,
#       'split_feature': 5,
#       'split_gain': 2.156749963760376,
#       'threshold': 16.400000000000002,
#       'decision_type': '<=',
#       'default_left': True,
#       'missing_type': 'None',
#       'internal_value': 0.0717523,
#       'internal_count': 66,
#       'left_child': {'split_index': 11,
#        'split_feature': 5,
#        'split_gain': 0.4199970066547394,
#        'threshold': 10.152100000000003,
#        'decision_type': '<=',
#        'default_left': True,
#        'missing_type': 'None',
#        'internal_value': 0.312729,
#        'internal_count': 46,
#        'left_child': {'leaf_index': 2,
#         'leaf_value': 0.01136735370120762,
#         'leaf_count': 26},
#        'right_child': {'leaf_index': 12,
#         'leaf_value': 0.042310753446435555,
#         'leaf_count': 20}},
#       'right_child': {'leaf_index': 5,
#        'leaf_value': -0.03842285723251008,
#        'leaf_count': 20}}},
#     'right_child': {'split_index': 2,
#      'split_feature': 0,
#      'split_gain': 12.964099884033203,
#      'threshold': 1.5000000000000002,
#      'decision_type': '<=',
#      'default_left': True,
#      'missing_type': 'None',
#      'internal_value': -0.690514,
#      'internal_count': 248,
#      'left_child': {'split_index': 5,
#       'split_feature': 5,
#       'split_gain': 1.0166900157928467,
#       'threshold': 58.689600000000006,
#       'decision_type': '<=',
#       'default_left': True,
#       'missing_type': 'None',
#       'internal_value': 0.193469,
#       'internal_count': 55,
#       'left_child': {'leaf_index': 1,
#        'leaf_value': 0.032865235944602576,
#        'leaf_count': 34},
#       'right_child': {'leaf_index': 6,
#        'leaf_value': -0.013067294366844525,
#        'leaf_count': 21}},
#      'right_child': {'split_index': 3,
#       'split_feature': 4,
#       'split_gain': 3.4588799476623535,
#       'threshold': 1.0000000180025095e-35,
#       'decision_type': '<=',
#       'default_left': True,
#       'missing_type': 'None',
#       'internal_value': -0.949103,
#       'internal_count': 193,
#       'left_child': {'split_index': 6,
#        'split_feature': 5,
#        'split_gain': 0.47242599725723267,
#        'threshold': 7.910400000000001,
#        'decision_type': '<=',
#        'default_left': True,
#        'missing_type': 'None',
#        'internal_value': -1.06102,
#        'internal_count': 167,
#        'left_child': {'split_index': 8,
#         'split_feature': 5,
#         'split_gain': 0.7414090037345886,
#         'threshold': 7.8646,
#         'decision_type': '<=',
#         'default_left': True,
#         'missing_type': 'None',
#         'internal_value': -1.18348,
#         'internal_count': 76,
#         'left_child': {'split_index': 13,
#          'split_feature': 5,
#          'split_gain': 0.15995000302791595,
#          'threshold': 7.745850000000001,
#          'decision_type': '<=',
#          'default_left': True,
#          'missing_type': 'None',
#          'internal_value': -1.05946,
#          'internal_count': 56,
#          'left_child': {'leaf_index': 3,
#           'leaf_value': -0.09113258640789575,
#           'leaf_count': 34},
#          'right_child': {'leaf_index': 14,
#           'leaf_value': -0.07288189008397708,
#           'leaf_count': 22}},
#         'right_child': {'leaf_index': 9,
#          'leaf_value': -0.12139020308820997,
#          'leaf_count': 20}},
#        'right_child': {'split_index': 7,
#         'split_feature': 3,
#         'split_gain': 0.80628502368927,
#         'threshold': 1.0000000180025095e-35,
#         'decision_type': '<=',
#         'default_left': True,
#         'missing_type': 'None',
#         'internal_value': -0.959128,
#         'internal_count': 91,
#         'left_child': {'split_index': 9,
#          'split_feature': 0,
#          'split_gain': 0.5999590158462524,
#          'threshold': 2.5000000000000004,
#          'decision_type': '<=',
#          'default_left': True,
#          'missing_type': 'None',
#          'internal_value': -0.851227,
#          'internal_count': 70,
#          'left_child': {'leaf_index': 7,
#           'leaf_value': -0.08581049493279587,
#           'leaf_count': 29},
#          'right_child': {'split_index': 10,
#           'split_feature': 5,
#           'split_gain': 0.4291380047798157,
#           'threshold': 8.093750000000002,
#           'decision_type': '<=',
#           'default_left': True,
#           'missing_type': 'None',
#           'internal_value': -0.688149,
#           'internal_count': 41,
#           'left_child': {'leaf_index': 10,
#            'leaf_value': -0.07126723835982013,
#            'leaf_count': 21},
#           'right_child': {'leaf_index': 11,
#            'leaf_value': -0.03726067283935554,
#            'leaf_count': 20}}},
#         'right_child': {'leaf_index': 8,
#          'leaf_value': -0.10470554675173209,
#          'leaf_count': 21}}},
#       'right_child': {'leaf_index': 4,
#        'leaf_value': -0.019402542079844414,
#        'leaf_count': 26}}}}},
#   {'tree_index': 3,
#    'num_leaves': 14,
#    'num_cat': 0,
#    'shrinkage': 0.0792807,
#    'tree_structure': {'split_index': 0,
#     'split_feature': 0,
#     'split_gain': 36.787200927734375,
#     'threshold': 2.5000000000000004,
#     'decision_type': '<=',
#     'default_left': True,
#     'missing_type': 'None',
#     'internal_value': 0,
#     'internal_count': 390,
#     'left_child': {'split_index': 1,
#      'split_feature': 5,
#      'split_gain': 10.842399597167969,
#      'threshold': 12.675000000000002,
#      'decision_type': '<=',
#      'default_left': True,
#      'missing_type': 'None',
#      'internal_value': 0.688812,
#      'internal_count': 179,
#      'left_child': {'leaf_index': 0,
#       'leaf_value': -0.05827664124949861,
#       'leaf_count': 21},
#      'right_child': {'split_index': 2,
#       'split_feature': 4,
#       'split_gain': 4.9074602127075195,
#       'threshold': 1.0000000180025095e-35,
#       'decision_type': '<=',
#       'default_left': True,
#       'missing_type': 'None',
#       'internal_value': 0.868065,
#       'internal_count': 158,
#       'left_child': {'split_index': 4,
#        'split_feature': 6,
#        'split_gain': 3.2048099040985107,
#        'threshold': 1.0000000180025095e-35,
#        'decision_type': '<=',
#        'default_left': True,
#        'missing_type': 'None',
#        'internal_value': 0.634407,
#        'internal_count': 112,
#        'left_child': {'leaf_index': 2,
#         'leaf_value': 0.0922303064092494,
#         'leaf_count': 33},
#        'right_child': {'split_index': 10,
#         'split_feature': 5,
#         'split_gain': 1.2131999731063843,
#         'threshold': 26.266650000000002,
#         'decision_type': '<=',
#         'default_left': True,
#         'missing_type': 'None',
#         'internal_value': 0.406411,
#         'internal_count': 79,
#         'left_child': {'leaf_index': 5,
#          'leaf_value': 0.009775793662420151,
#          'leaf_count': 36},
#         'right_child': {'split_index': 12,
#          'split_feature': 5,
#          'split_gain': 0.00012188300024718046,
#          'threshold': 51.931250000000006,
#          'decision_type': '<=',
#          'default_left': True,
#          'missing_type': 'None',
#          'internal_value': 0.637173,
#          'internal_count': 43,
#          'left_child': {'leaf_index': 11,
#           'leaf_value': 0.050783777104645954,
#           'leaf_count': 22},
#          'right_child': {'leaf_index': 13,
#           'leaf_value': 0.05023638939273002,
#           'leaf_count': 21}}}},
#       'right_child': {'split_index': 8,
#        'split_feature': 5,
#        'split_gain': 1.517840027809143,
#        'threshold': 29.412500000000005,
#        'decision_type': '<=',
#        'default_left': True,
#        'missing_type': 'None',
#        'internal_value': 1.42472,
#        'internal_count': 46,
#        'left_child': {'leaf_index': 3,
#         'leaf_value': 0.1459732163912879,
#         'leaf_count': 20},
#        'right_child': {'leaf_index': 9,
#         'leaf_value': 0.08705217316525371,
#         'leaf_count': 26}}}},
#     'right_child': {'split_index': 3,
#      'split_feature': 6,
#      'split_gain': 3.6220600605010986,
#      'threshold': 1.0000000180025095e-35,
#      'decision_type': '<=',
#      'default_left': True,
#      'missing_type': 'None',
#      'internal_value': -0.587087,
#      'internal_count': 211,
#      'left_child': {'leaf_index': 1,
#       'leaf_value': 0.00305285061747122,
#       'leaf_count': 33},
#      'right_child': {'split_index': 5,
#       'split_feature': 3,
#       'split_gain': 2.9582600593566895,
#       'threshold': 1.5000000000000002,
#       'decision_type': '<=',
#       'default_left': True,
#       'missing_type': 'None',
#       'internal_value': -0.707003,
#       'internal_count': 178,
#       'left_child': {'split_index': 6,
#        'split_feature': 5,
#        'split_gain': 2.5671699047088623,
#        'threshold': 9.662500000000001,
#        'decision_type': '<=',
#        'default_left': True,
#        'missing_type': 'None',
#        'internal_value': -0.603966,
#        'internal_count': 156,
#        'left_child': {'split_index': 7,
#         'split_feature': 5,
#         'split_gain': 1.7396999597549438,
#         'threshold': 7.887500000000001,
#         'decision_type': '<=',
#         'default_left': True,
#         'missing_type': 'None',
#         'internal_value': -0.757186,
#         'internal_count': 119,
#         'left_child': {'split_index': 9,
#          'split_feature': 5,
#          'split_gain': 1.4468200206756592,
#          'threshold': 7.762500000000001,
#          'decision_type': '<=',
#          'default_left': True,
#          'missing_type': 'None',
#          'internal_value': -0.50087,
#          'internal_count': 59,
#          'left_child': {'leaf_index': 4,
#           'leaf_value': -0.05859862427550032,
#           'leaf_count': 39},
#          'right_child': {'leaf_index': 10,
#           'leaf_value': -0.0035155601978194293,
#           'leaf_count': 20}},
#         'right_child': {'split_index': 11,
#          'split_feature': 5,
#          'split_gain': 0.03809129819273949,
#          'threshold': 7.987500000000002,
#          'decision_type': '<=',
#          'default_left': True,
#          'missing_type': 'None',
#          'internal_value': -1.01114,
#          'internal_count': 60,
#          'left_child': {'leaf_index': 8,
#           'leaf_value': -0.07492508896763185,
#           'leaf_count': 24},
#          'right_child': {'leaf_index': 12,
#           'leaf_value': -0.08356790516035155,
#           'leaf_count': 36}}},
#        'right_child': {'leaf_index': 7,
#         'leaf_value': -0.010330045075540568,
#         'leaf_count': 37}},
#       'right_child': {'leaf_index': 6,
#        'leaf_value': -0.11223200344803806,
#        'leaf_count': 22}}}}},
#   {'tree_index': 4,
#    'num_leaves': 15,
#    'num_cat': 0,
#    'shrinkage': 0.0792807,
#    'tree_structure': {'split_index': 0,
#     'split_feature': 0,
#     'split_gain': 36.0703010559082,
#     'threshold': 2.5000000000000004,
#     'decision_type': '<=',
#     'default_left': True,
#     'missing_type': 'None',
#     'internal_value': 0,
#     'internal_count': 390,
#     'left_child': {'split_index': 1,
#      'split_feature': 2,
#      'split_gain': 9.359760284423828,
#      'threshold': 50.50000000000001,
#      'decision_type': '<=',
#      'default_left': True,
#      'missing_type': 'NaN',
#      'internal_value': 0.673649,
#      'internal_count': 169,
#      'left_child': {'split_index': 2,
#       'split_feature': 5,
#       'split_gain': 7.2345099449157715,
#       'threshold': 13.208350000000001,
#       'decision_type': '<=',
#       'default_left': True,
#       'missing_type': 'None',
#       'internal_value': 0.851642,
#       'internal_count': 148,
#       'left_child': {'leaf_index': 0,
#        'leaf_value': 0.00023589787908465714,
#        'leaf_count': 34},
#       'right_child': {'split_index': 8,
#        'split_feature': 2,
#        'split_gain': 3.1410200595855713,
#        'threshold': 36.25000000000001,
#        'decision_type': '<=',
#        'default_left': True,
#        'missing_type': 'NaN',
#        'internal_value': 1.09121,
#        'internal_count': 114,
#        'left_child': {'split_index': 11,
#         'split_feature': 2,
#         'split_gain': 0.4964909851551056,
#         'threshold': 15.500000000000002,
#         'decision_type': '<=',
#         'default_left': True,
#         'missing_type': 'NaN',
#         'internal_value': 1.27742,
#         'internal_count': 87,
#         'left_child': {'leaf_index': 3,
#          'leaf_value': 0.11881013025658602,
#          'leaf_count': 28},
#         'right_child': {'split_index': 12,
#          'split_feature': 0,
#          'split_gain': 2.6909499168395996,
#          'threshold': 1.5000000000000002,
#          'decision_type': '<=',
#          'default_left': True,
#          'missing_type': 'None',
#          'internal_value': 1.17175,
#          'internal_count': 59,
#          'left_child': {'leaf_index': 12,
#           'leaf_value': 0.11909701721271344,
#           'leaf_count': 37},
#          'right_child': {'leaf_index': 13,
#           'leaf_value': 0.047988210038060704,
#           'leaf_count': 22}}},
#        'right_child': {'leaf_index': 9,
#         'leaf_value': 0.03831925444786029,
#         'leaf_count': 27}}},
#      'right_child': {'leaf_index': 2,
#       'leaf_value': -0.049643098731048343,
#       'leaf_count': 21}},
#     'right_child': {'split_index': 3,
#      'split_feature': 2,
#      'split_gain': 3.8191800117492676,
#      'threshold': 27.500000000000004,
#      'decision_type': '<=',
#      'default_left': True,
#      'missing_type': 'NaN',
#      'internal_value': -0.596859,
#      'internal_count': 221,
#      'left_child': {'split_index': 4,
#       'split_feature': 5,
#       'split_gain': 4.622529983520508,
#       'threshold': 19.379150000000003,
#       'decision_type': '<=',
#       'default_left': True,
#       'missing_type': 'None',
#       'internal_value': -0.435945,
#       'internal_count': 165,
#       'left_child': {'split_index': 5,
#        'split_feature': 5,
#        'split_gain': 5.685480117797852,
#        'threshold': 15.1729,
#        'decision_type': '<=',
#        'default_left': True,
#        'missing_type': 'None',
#        'internal_value': -0.279512,
#        'internal_count': 138,
#        'left_child': {'split_index': 6,
#         'split_feature': 2,
#         'split_gain': 4.4685797691345215,
#         'threshold': 19.500000000000004,
#         'decision_type': '<=',
#         'default_left': False,
#         'missing_type': 'NaN',
#         'internal_value': -0.458797,
#         'internal_count': 118,
#         'left_child': {'leaf_index': 1,
#          'leaf_value': 0.027567013921797584,
#          'leaf_count': 23},
#         'right_child': {'split_index': 7,
#          'split_feature': 5,
#          'split_gain': 4.640989780426025,
#          'threshold': 7.887500000000001,
#          'decision_type': '<=',
#          'default_left': True,
#          'missing_type': 'None',
#          'internal_value': -0.668012,
#          'internal_count': 95,
#          'left_child': {'split_index': 13,
#           'split_feature': 2,
#           'split_gain': 0.16023500263690948,
#           'threshold': 26.500000000000004,
#           'decision_type': '<=',
#           'default_left': False,
#           'missing_type': 'NaN',
#           'internal_value': -0.251748,
#           'internal_count': 53,
#           'left_child': {'leaf_index': 7,
#            'leaf_value': -0.03018592674408049,
#            'leaf_count': 24},
#           'right_child': {'leaf_index': 14,
#            'leaf_value': -0.01159891507083603,
#            'leaf_count': 29}},
#          'right_child': {'split_index': 9,
#           'split_feature': 2,
#           'split_gain': 0.804527997970581,
#           'threshold': 19.500000000000004,
#           'decision_type': '<=',
#           'default_left': True,
#           'missing_type': 'NaN',
#           'internal_value': -1.19822,
#           'internal_count': 42,
#           'left_child': {'leaf_index': 8,
#            'leaf_value': -0.11771063770476094,
#            'leaf_count': 22},
#           'right_child': {'leaf_index': 10,
#            'leaf_value': -0.07092433000211609,
#            'leaf_count': 20}}}},
#        'right_child': {'leaf_index': 6,
#         'leaf_value': 0.05856115961444372,
#         'leaf_count': 20}},
#       'right_child': {'leaf_index': 5,
#        'leaf_value': -0.09737670560981343,
#        'leaf_count': 27}},
#      'right_child': {'split_index': 10,
#       'split_feature': 5,
#       'split_gain': 0.6075819730758667,
#       'threshold': 7.910400000000001,
#       'decision_type': '<=',
#       'default_left': True,
#       'missing_type': 'None',
#       'internal_value': -1.07232,
#       'internal_count': 56,
#       'left_child': {'leaf_index': 4,
#        'leaf_value': -0.10533348992415978,
#        'leaf_count': 24},
#       'right_child': {'leaf_index': 11,
#        'leaf_value': -0.07012426317866383,
#        'leaf_count': 32}}}}},
#   {'tree_index': 5,
#    'num_leaves': 14,
#    'num_cat': 0,
#    'shrinkage': 0.0792807,
#    'tree_structure': {'split_index': 0,
#     'split_feature': 1,
#     'split_gain': 56.417598724365234,
#     'threshold': 1.0000000180025095e-35,
#     'decision_type': '<=',
#     'default_left': True,
#     'missing_type': 'None',
#     'internal_value': 0,
#     'internal_count': 390,
#     'left_child': {'split_index': 1,
#      'split_feature': 5,
#      'split_gain': 9.334830284118652,
#      'threshold': 31.33125,
#      'decision_type': '<=',
#      'default_left': True,
#      'missing_type': 'None',
#      'internal_value': 0.936968,
#      'internal_count': 148,
#      'left_child': {'split_index': 5,
#       'split_feature': 2,
#       'split_gain': 1.9830000400543213,
#       'threshold': 36.25000000000001,
#       'decision_type': '<=',
#       'default_left': False,
#       'missing_type': 'NaN',
#       'internal_value': 0.60372,
#       'internal_count': 104,
#       'left_child': {'split_index': 6,
#        'split_feature': 3,
#        'split_gain': 2.0160999298095703,
#        'threshold': 1.0000000180025095e-35,
#        'decision_type': '<=',
#        'default_left': True,
#        'missing_type': 'None',
#        'internal_value': 0.78416,
#        'internal_count': 73,
#        'left_child': {'split_index': 7,
#         'split_feature': 5,
#         'split_gain': 2.291520118713379,
#         'threshold': 10.816650000000001,
#         'decision_type': '<=',
#         'default_left': True,
#         'missing_type': 'None',
#         'internal_value': 1.02492,
#         'internal_count': 48,
#         'left_child': {'leaf_index': 0,
#          'leaf_value': 0.03968601250775667,
#          'leaf_count': 20},
#         'right_child': {'leaf_index': 8,
#          'leaf_value': 0.1105967411914993,
#          'leaf_count': 28}},
#        'right_child': {'leaf_index': 7,
#         'leaf_value': 0.025036683144196763,
#         'leaf_count': 25}},
#       'right_child': {'leaf_index': 6,
#        'leaf_value': 0.013437407487946288,
#        'leaf_count': 31}},
#      'right_child': {'split_index': 10,
#       'split_feature': 5,
#       'split_gain': 0.5962460041046143,
#       'threshold': 79.60000000000001,
#       'decision_type': '<=',
#       'default_left': True,
#       'missing_type': 'None',
#       'internal_value': 1.71052,
#       'internal_count': 44,
#       'left_child': {'leaf_index': 2,
#        'leaf_value': 0.1525593907355105,
#        'leaf_count': 24},
#       'right_child': {'leaf_index': 11,
#        'leaf_value': 0.11533031733257151,
#        'leaf_count': 20}}},
#     'right_child': {'split_index': 2,
#      'split_feature': 5,
#      'split_gain': 8.752579689025879,
#      'threshold': 51.931250000000006,
#      'decision_type': '<=',
#      'default_left': True,
#      'missing_type': 'None',
#      'internal_value': -0.679813,
#      'internal_count': 242,
#      'left_child': {'split_index': 3,
#       'split_feature': 5,
#       'split_gain': 2.628959894180298,
#       'threshold': 15.1729,
#       'decision_type': '<=',
#       'default_left': True,
#       'missing_type': 'None',
#       'internal_value': -0.826227,
#       'internal_count': 216,
#       'left_child': {'split_index': 8,
#        'split_feature': 2,
#        'split_gain': 1.0274100303649902,
#        'threshold': 27.500000000000004,
#        'decision_type': '<=',
#        'default_left': False,
#        'missing_type': 'NaN',
#        'internal_value': -0.988602,
#        'internal_count': 150,
#        'left_child': {'split_index': 9,
#         'split_feature': 5,
#         'split_gain': 0.8200169801712036,
#         'threshold': 7.781250000000001,
#         'decision_type': '<=',
#         'default_left': True,
#         'missing_type': 'None',
#         'internal_value': -0.741122,
#         'internal_count': 51,
#         'left_child': {'leaf_index': 1,
#          'leaf_value': -0.03405653136457286,
#          'leaf_count': 22},
#         'right_child': {'leaf_index': 10,
#          'leaf_value': -0.07770541146948873,
#          'leaf_count': 29}},
#        'right_child': {'split_index': 11,
#         'split_feature': 5,
#         'split_gain': 0.42149999737739563,
#         'threshold': 7.762500000000001,
#         'decision_type': '<=',
#         'default_left': True,
#         'missing_type': 'None',
#         'internal_value': -1.11811,
#         'internal_count': 99,
#         'left_child': {'leaf_index': 9,
#          'leaf_value': -0.10440688284746619,
#          'leaf_count': 33},
#         'right_child': {'split_index': 12,
#          'split_feature': 2,
#          'split_gain': 0.38308000564575195,
#          'threshold': 41.50000000000001,
#          'decision_type': '<=',
#          'default_left': False,
#          'missing_type': 'NaN',
#          'internal_value': -1.01736,
#          'internal_count': 66,
#          'left_child': {'leaf_index': 12,
#           'leaf_value': -0.09356192345747558,
#           'leaf_count': 33},
#          'right_child': {'leaf_index': 13,
#           'leaf_value': -0.06729774756689814,
#           'leaf_count': 33}}}},
#       'right_child': {'split_index': 4,
#        'split_feature': 5,
#        'split_gain': 3.254189968109131,
#        'threshold': 27.135400000000004,
#        'decision_type': '<=',
#        'default_left': True,
#        'missing_type': 'None',
#        'internal_value': -0.483524,
#        'internal_count': 66,
#        'left_child': {'leaf_index': 4,
#         'leaf_value': -0.0065060338969755984,
#         'leaf_count': 38},
#        'right_child': {'leaf_index': 5,
#         'leaf_value': -0.08064545405799137,
#         'leaf_count': 28}}},
#      'right_child': {'leaf_index': 3,
#       'leaf_value': 0.034813190476273057,
#       'leaf_count': 26}}}},
#   {'tree_index': 6,
#    'num_leaves': 11,
#    'num_cat': 0,
#    'shrinkage': 0.0792807,
#    'tree_structure': {'split_index': 0,
#     'split_feature': 1,
#     'split_gain': 48.37229919433594,
#     'threshold': 1.0000000180025095e-35,
#     'decision_type': '<=',
#     'default_left': True,
#     'missing_type': 'None',
#     'internal_value': 0,
#     'internal_count': 390,
#     'left_child': {'split_index': 1,
#      'split_feature': 0,
#      'split_gain': 20.96769905090332,
#      'threshold': 2.5000000000000004,
#      'decision_type': '<=',
#      'default_left': True,
#      'missing_type': 'None',
#      'internal_value': 0.864372,
#      'internal_count': 148,
#      'left_child': {'split_index': 8,
#       'split_feature': 3,
#       'split_gain': 0.17980100214481354,
#       'threshold': 1.0000000180025095e-35,
#       'decision_type': '<=',
#       'default_left': True,
#       'missing_type': 'None',
#       'internal_value': 1.57905,
#       'internal_count': 78,
#       'left_child': {'split_index': 9,
#        'split_feature': 0,
#        'split_gain': 0.0540631003677845,
#        'threshold': 1.5000000000000002,
#        'decision_type': '<=',
#        'default_left': True,
#        'missing_type': 'None',
#        'internal_value': 1.66419,
#        'internal_count': 44,
#        'left_child': {'leaf_index': 0,
#         'leaf_value': 0.13759440919410706,
#         'leaf_count': 22},
#        'right_child': {'leaf_index': 10,
#         'leaf_value': 0.12639091075859804,
#         'leaf_count': 22}},
#       'right_child': {'leaf_index': 9,
#        'leaf_value': 0.11647769046341844,
#        'leaf_count': 34}},
#      'right_child': {'split_index': 3,
#       'split_feature': 6,
#       'split_gain': 4.377709865570068,
#       'threshold': 1.5000000000000002,
#       'decision_type': '<=',
#       'default_left': True,
#       'missing_type': 'None',
#       'internal_value': 0.0527516,
#       'internal_count': 70,
#       'left_child': {'leaf_index': 2,
#        'leaf_value': 0.05176451393656621,
#        'leaf_count': 29},
#       'right_child': {'leaf_index': 4,
#        'leaf_value': -0.029982478168173843,
#        'leaf_count': 41}}},
#     'right_child': {'split_index': 2,
#      'split_feature': 0,
#      'split_gain': 8.680549621582031,
#      'threshold': 1.5000000000000002,
#      'decision_type': '<=',
#      'default_left': True,
#      'missing_type': 'None',
#      'internal_value': -0.639687,
#      'internal_count': 242,
#      'left_child': {'leaf_index': 1,
#       'leaf_value': 0.009513774286725814,
#       'leaf_count': 49},
#      'right_child': {'split_index': 4,
#       'split_feature': 6,
#       'split_gain': 2.829479932785034,
#       'threshold': 1.0000000180025095e-35,
#       'decision_type': '<=',
#       'default_left': True,
#       'missing_type': 'None',
#       'internal_value': -0.85796,
#       'internal_count': 193,
#       'left_child': {'leaf_index': 3,
#        'leaf_value': -0.01894924574456142,
#        'leaf_count': 28},
#       'right_child': {'split_index': 5,
#        'split_feature': 6,
#        'split_gain': 0.9782299995422363,
#        'threshold': 1.5000000000000002,
#        'decision_type': '<=',
#        'default_left': True,
#        'missing_type': 'None',
#        'internal_value': -0.970376,
#        'internal_count': 165,
#        'left_child': {'leaf_index': 5,
#         'leaf_value': -0.11138512656858286,
#         'leaf_count': 22},
#        'right_child': {'split_index': 6,
#         'split_feature': 4,
#         'split_gain': 0.7259079813957214,
#         'threshold': 1.0000000180025095e-35,
#         'decision_type': '<=',
#         'default_left': True,
#         'missing_type': 'None',
#         'internal_value': -0.904967,
#         'internal_count': 143,
#         'left_child': {'split_index': 7,
#          'split_feature': 0,
#          'split_gain': 0.8220430016517639,
#          'threshold': 2.5000000000000004,
#          'decision_type': '<=',
#          'default_left': True,
#          'missing_type': 'None',
#          'internal_value': -0.975792,
#          'internal_count': 120,
#          'left_child': {'leaf_index': 6,
#           'leaf_value': -0.10239713055731967,
#           'leaf_count': 29},
#          'right_child': {'leaf_index': 8,
#           'leaf_value': -0.06903585694220085,
#           'leaf_count': 91}},
#         'right_child': {'leaf_index': 7,
#          'leaf_value': -0.04458132416162135,
#          'leaf_count': 23}}}}}}},
#   {'tree_index': 7,
#    'num_leaves': 11,
#    'num_cat': 0,
#    'shrinkage': 0.0792807,
#    'tree_structure': {'split_index': 0,
#     'split_feature': 1,
#     'split_gain': 41.6703987121582,
#     'threshold': 1.0000000180025095e-35,
#     'decision_type': '<=',
#     'default_left': True,
#     'missing_type': 'None',
#     'internal_value': 0,
#     'internal_count': 390,
#     'left_child': {'split_index': 1,
#      'split_feature': 0,
#      'split_gain': 18.245899200439453,
#      'threshold': 2.5000000000000004,
#      'decision_type': '<=',
#      'default_left': True,
#      'missing_type': 'None',
#      'internal_value': 0.803033,
#      'internal_count': 148,
#      'left_child': {'split_index': 8,
#       'split_feature': 6,
#       'split_gain': 0.20361000299453735,
#       'threshold': 1.5000000000000002,
#       'decision_type': '<=',
#       'default_left': True,
#       'missing_type': 'None',
#       'internal_value': 1.47764,
#       'internal_count': 78,
#       'left_child': {'leaf_index': 0,
#        'leaf_value': 0.13131806480073688,
#        'leaf_count': 20},
#       'right_child': {'split_index': 9,
#        'split_feature': 3,
#        'split_gain': 0.253930002450943,
#        'threshold': 1.0000000180025095e-35,
#        'decision_type': '<=',
#        'default_left': True,
#        'missing_type': 'None',
#        'internal_value': 1.41744,
#        'internal_count': 58,
#        'left_child': {'leaf_index': 9,
#         'leaf_value': 0.121622902265828,
#         'leaf_count': 33},
#        'right_child': {'leaf_index': 10,
#         'leaf_value': 0.10018343287025823,
#         'leaf_count': 25}}},
#      'right_child': {'split_index': 3,
#       'split_feature': 6,
#       'split_gain': 3.6996099948883057,
#       'threshold': 1.5000000000000002,
#       'decision_type': '<=',
#       'default_left': True,
#       'missing_type': 'None',
#       'internal_value': 0.0484638,
#       'internal_count': 70,
#       'left_child': {'leaf_index': 2,
#        'leaf_value': 0.047319899104599945,
#        'leaf_count': 29},
#       'right_child': {'leaf_index': 4,
#        'leaf_value': -0.027769231770222877,
#        'leaf_count': 41}}},
#     'right_child': {'split_index': 2,
#      'split_feature': 0,
#      'split_gain': 7.7094597816467285,
#      'threshold': 1.5000000000000002,
#      'decision_type': '<=',
#      'default_left': True,
#      'missing_type': 'None',
#      'internal_value': -0.602579,
#      'internal_count': 242,
#      'left_child': {'leaf_index': 1,
#       'leaf_value': 0.00874256247793372,
#       'leaf_count': 49},
#      'right_child': {'split_index': 4,
#       'split_feature': 6,
#       'split_gain': 2.584439992904663,
#       'threshold': 1.0000000180025095e-35,
#       'decision_type': '<=',
#       'default_left': True,
#       'missing_type': 'None',
#       'internal_value': -0.813631,
#       'internal_count': 193,
#       'left_child': {'leaf_index': 3,
#        'leaf_value': -0.017558883700950614,
#        'leaf_count': 28},
#       'right_child': {'split_index': 5,
#        'split_feature': 6,
#        'split_gain': 0.9444389939308167,
#        'threshold': 1.5000000000000002,
#        'decision_type': '<=',
#        'default_left': True,
#        'missing_type': 'None',
#        'internal_value': -0.92402,
#        'internal_count': 165,
#        'left_child': {'leaf_index': 5,
#         'leaf_value': -0.10800763999764168,
#         'leaf_count': 22},
#        'right_child': {'split_index': 6,
#         'split_feature': 4,
#         'split_gain': 0.6818310022354126,
#         'threshold': 1.0000000180025095e-35,
#         'decision_type': '<=',
#         'default_left': True,
#         'missing_type': 'None',
#         'internal_value': -0.859364,
#         'internal_count': 143,
#         'left_child': {'split_index': 7,
#          'split_feature': 0,
#          'split_gain': 0.7646440267562866,
#          'threshold': 2.5000000000000004,
#          'decision_type': '<=',
#          'default_left': True,
#          'missing_type': 'None',
#          'internal_value': -0.929677,
#          'internal_count': 120,
#          'left_child': {'leaf_index': 6,
#           'leaf_value': -0.0983834295904221,
#           'leaf_count': 29},
#          'right_child': {'leaf_index': 8,
#           'leaf_value': -0.06558718653301324,
#           'leaf_count': 91}},
#         'right_child': {'leaf_index': 7,
#          'leaf_value': -0.04165857776063303,
#          'leaf_count': 23}}}}}}},
#   {'tree_index': 8,
#    'num_leaves': 15,
#    'num_cat': 0,
#    'shrinkage': 0.0792807,
#    'tree_structure': {'split_index': 0,
#     'split_feature': 1,
#     'split_gain': 39.362998962402344,
#     'threshold': 1.0000000180025095e-35,
#     'decision_type': '<=',
#     'default_left': True,
#     'missing_type': 'None',
#     'internal_value': 0,
#     'internal_count': 390,
#     'left_child': {'split_index': 1,
#      'split_feature': 0,
#      'split_gain': 14.48330020904541,
#      'threshold': 2.5000000000000004,
#      'decision_type': '<=',
#      'default_left': True,
#      'missing_type': 'None',
#      'internal_value': 0.747917,
#      'internal_count': 141,
#      'left_child': {'split_index': 11,
#       'split_feature': 2,
#       'split_gain': 0.5382959842681885,
#       'threshold': 25.500000000000004,
#       'decision_type': '<=',
#       'default_left': False,
#       'missing_type': 'NaN',
#       'internal_value': 1.3765,
#       'internal_count': 74,
#       'left_child': {'leaf_index': 0,
#        'leaf_value': 0.09065591268726753,
#        'leaf_count': 27},
#       'right_child': {'split_index': 12,
#        'split_feature': 2,
#        'split_gain': 0.5083490014076233,
#        'threshold': 42.50000000000001,
#        'decision_type': '<=',
#        'default_left': False,
#        'missing_type': 'NaN',
#        'internal_value': 1.50797,
#        'internal_count': 47,
#        'left_child': {'leaf_index': 12,
#         'leaf_value': 0.13466935280159825,
#         'leaf_count': 26},
#        'right_child': {'leaf_index': 13,
#         'leaf_value': 0.10073632989133681,
#         'leaf_count': 21}}},
#      'right_child': {'split_index': 2,
#       'split_feature': 2,
#       'split_gain': 4.396890163421631,
#       'threshold': 1.5000000000000002,
#       'decision_type': '<=',
#       'default_left': True,
#       'missing_type': 'NaN',
#       'internal_value': 0.0651966,
#       'internal_count': 67,
#       'left_child': {'leaf_index': 2,
#        'leaf_value': 0.062311653274564824,
#        'leaf_count': 23},
#       'right_child': {'split_index': 9,
#        'split_feature': 2,
#        'split_gain': 1.1629199981689453,
#        'threshold': 19.500000000000004,
#        'decision_type': '<=',
#        'default_left': True,
#        'missing_type': 'NaN',
#        'internal_value': -0.311882,
#        'internal_count': 44,
#        'left_child': {'leaf_index': 3,
#         'leaf_value': 0.002762159871012333,
#         'leaf_count': 21},
#        'right_child': {'leaf_index': 10,
#         'leaf_value': -0.0497619759407624,
#         'leaf_count': 23}}}},
#     'right_child': {'split_index': 3,
#      'split_feature': 6,
#      'split_gain': 3.4024300575256348,
#      'threshold': 1.0000000180025095e-35,
#      'decision_type': '<=',
#      'default_left': True,
#      'missing_type': 'None',
#      'internal_value': -0.639892,
#      'internal_count': 249,
#      'left_child': {'split_index': 4,
#       'split_feature': 2,
#       'split_gain': 3.6324000358581543,
#       'threshold': 26.500000000000004,
#       'decision_type': '<=',
#       'default_left': True,
#       'missing_type': 'NaN',
#       'internal_value': -0.146169,
#       'internal_count': 48,
#       'left_child': {'leaf_index': 1,
#        'leaf_value': 0.028832263706247814,
#        'leaf_count': 27},
#       'right_child': {'leaf_index': 5,
#        'leaf_value': -0.0629563238889199,
#        'leaf_count': 21}},
#      'right_child': {'split_index': 5,
#       'split_feature': 6,
#       'split_gain': 1.49468994140625,
#       'threshold': 1.5000000000000002,
#       'decision_type': '<=',
#       'default_left': True,
#       'missing_type': 'None',
#       'internal_value': -0.772888,
#       'internal_count': 201,
#       'left_child': {'leaf_index': 4,
#        'leaf_value': -0.10654879570469582,
#        'leaf_count': 22},
#       'right_child': {'split_index': 6,
#        'split_feature': 2,
#        'split_gain': 1.3188199996948242,
#        'threshold': 17.500000000000004,
#        'decision_type': '<=',
#        'default_left': False,
#        'missing_type': 'NaN',
#        'internal_value': -0.708768,
#        'internal_count': 179,
# ...
#         'leaf_count': 25},
#        'right_child': {'leaf_index': 11,
#         'leaf_value': -0.027738969693877017,
#         'leaf_count': 20}}}},
#     'right_child': {'split_index': 3,
#      'split_feature': 5,
#      'split_gain': 0.7449089884757996,
#      'threshold': 27.135400000000004,
#      'decision_type': '<=',
#      'default_left': True,
#      'missing_type': 'None',
#      'internal_value': -0.146821,
#      'internal_count': 249,
#      'left_child': {'split_index': 4,
#       'split_feature': 5,
#       'split_gain': 1.4496999979019165,
#       'threshold': 7.910400000000001,
#       'decision_type': '<=',
#       'default_left': True,
#       'missing_type': 'None',
#       'internal_value': -0.0335067,
#       'internal_count': 193,
#       'left_child': {'split_index': 6,
#        'split_feature': 5,
#        'split_gain': 0.8628749847412109,
#        'threshold': 7.8646,
#        'decision_type': '<=',
#        'default_left': True,
#        'missing_type': 'None',
#        'internal_value': -0.386569,
#        'internal_count': 85,
#        'left_child': {'split_index': 8,
#         'split_feature': 5,
#         'split_gain': 0.3371109962463379,
#         'threshold': 7.745850000000001,
#         'decision_type': '<=',
#         'default_left': True,
#         'missing_type': 'None',
#         'internal_value': -0.22268,
#         'internal_count': 65,
#         'left_child': {'split_index': 9,
#          'split_feature': 6,
#          'split_gain': 0.3516330122947693,
#          'threshold': 1.5000000000000002,
#          'decision_type': '<=',
#          'default_left': True,
#          'missing_type': 'None',
#          'internal_value': -0.362742,
#          'internal_count': 45,
#          'left_child': {'leaf_index': 1,
#           'leaf_value': -0.008024877440222252,
#           'leaf_count': 21},
#          'right_child': {'leaf_index': 10,
#           'leaf_value': -0.05279467784583347,
#           'leaf_count': 24}},
#         'right_child': {'leaf_index': 9,
#          'leaf_value': 0.01426819592710156,
#          'leaf_count': 20}},
#        'right_child': {'leaf_index': 7,
#         'leaf_value': -0.08748368374471409,
#         'leaf_count': 20}},
#       'right_child': {'split_index': 11,
#        'split_feature': 5,
#        'split_gain': 0.22588199377059937,
#        'threshold': 8.093750000000002,
#        'decision_type': '<=',
#        'default_left': True,
#        'missing_type': 'None',
#        'internal_value': 0.172529,
#        'internal_count': 108,
#        'left_child': {'leaf_index': 5,
#         'leaf_value': 0.03961676681115345,
#         'leaf_count': 20},
#        'right_child': {'split_index': 12,
#         'split_feature': 5,
#         'split_gain': 0.33095699548721313,
#         'threshold': 25.5271,
#         'decision_type': '<=',
#         'default_left': True,
#         'missing_type': 'None',
#         'internal_value': 0.117669,
#         'internal_count': 88,
#         'left_child': {'split_index': 13,
#          'split_feature': 5,
#          'split_gain': 0.33160701394081116,
#          'threshold': 14.427100000000001,
#          'decision_type': '<=',
#          'default_left': True,
#          'missing_type': 'None',
#          'internal_value': 0.00189502,
#          'internal_count': 67,
#          'left_child': {'leaf_index': 12,
#           'leaf_value': 0.015034179365553239,
#           'leaf_count': 40},
#          'right_child': {'leaf_index': 14,
#           'leaf_value': -0.018514325736343047,
#           'leaf_count': 27}},
#         'right_child': {'leaf_index': 13,
#          'leaf_value': 0.03035712015345929,
#          'leaf_count': 21}}}},
#      'right_child': {'split_index': 5,
#       'split_feature': 5,
#       'split_gain': 0.9897869825363159,
#       'threshold': 51.931250000000006,
#       'decision_type': '<=',
#       'default_left': True,
#       'missing_type': 'None',
#       'internal_value': -0.363369,
#       'internal_count': 56,
#       'left_child': {'leaf_index': 4,
#        'leaf_value': -0.054304070105059644,
#        'leaf_count': 29},
#       'right_child': {'leaf_index': 6,
#        'leaf_value': -0.005409673881846472,
#        'leaf_count': 27}}}}},
#   {'tree_index': 58,
#    'num_leaves': 14,
#    'num_cat': 0,
#    'shrinkage': 0.0792807,
#    'tree_structure': {'split_index': 0,
#     'split_feature': 1,
#     'split_gain': 1.4369200468063354,
#     'threshold': 1.0000000180025095e-35,
#     'decision_type': '<=',
#     'default_left': True,
#     'missing_type': 'None',
#     'internal_value': 0,
#     'internal_count': 390,
#     'left_child': {'split_index': 1,
#      'split_feature': 0,
#      'split_gain': 1.3594599962234497,
#      'threshold': 2.5000000000000004,
#      'decision_type': '<=',
#      'default_left': True,
#      'missing_type': 'None',
#      'internal_value': 0.213972,
#      'internal_count': 141,
#      'left_child': {'split_index': 4,
#       'split_feature': 2,
#       'split_gain': 0.767641007900238,
#       'threshold': 24.500000000000004,
#       'decision_type': '<=',
#       'default_left': True,
#       'missing_type': 'NaN',
#       'internal_value': 0.625926,
#       'internal_count': 76,
#       'left_child': {'leaf_index': 0,
#        'leaf_value': 0.08914574938991704,
#        'leaf_count': 31},
#       'right_child': {'split_index': 10,
#        'split_feature': 2,
#        'split_gain': 0.127251997590065,
#        'threshold': 35.50000000000001,
#        'decision_type': '<=',
#        'default_left': True,
#        'missing_type': 'NaN',
#        'internal_value': 0.353233,
#        'internal_count': 45,
#        'left_child': {'leaf_index': 5,
#         'leaf_value': 0.04322944780782277,
#         'leaf_count': 25},
#        'right_child': {'leaf_index': 11,
#         'leaf_value': 0.013612360203374311,
#         'leaf_count': 20}}},
#      'right_child': {'split_index': 2,
#       'split_feature': 2,
#       'split_gain': 1.2988899946212769,
#       'threshold': 1.5000000000000002,
#       'decision_type': '<=',
#       'default_left': True,
#       'missing_type': 'NaN',
#       'internal_value': 0.0415339,
#       'internal_count': 65,
#       'left_child': {'leaf_index': 2,
#        'leaf_value': 0.0381676831279164,
#        'leaf_count': 23},
#       'right_child': {'split_index': 11,
#        'split_feature': 2,
#        'split_gain': 0.019501499831676483,
#        'threshold': 19.500000000000004,
#        'decision_type': '<=',
#        'default_left': True,
#        'missing_type': 'NaN',
#        'internal_value': -0.177341,
#        'internal_count': 42,
#        'left_child': {'leaf_index': 3,
#         'leaf_value': -0.010349986232131164,
#         'leaf_count': 21},
#        'right_child': {'leaf_index': 12,
#         'leaf_value': -0.017727611695838023,
#         'leaf_count': 21}}}},
#     'right_child': {'split_index': 3,
#      'split_feature': 2,
#      'split_gain': 0.8816710114479065,
#      'threshold': 16.500000000000004,
#      'decision_type': '<=',
#      'default_left': False,
#      'missing_type': 'NaN',
#      'internal_value': -0.136289,
#      'internal_count': 249,
#      'left_child': {'leaf_index': 1,
#       'leaf_value': 0.029455276202687904,
#       'leaf_count': 20},
#      'right_child': {'split_index': 5,
#       'split_feature': 2,
#       'split_gain': 0.5796110033988953,
#       'threshold': 19.500000000000004,
#       'decision_type': '<=',
#       'default_left': True,
#       'missing_type': 'NaN',
#       'internal_value': -0.193802,
#       'internal_count': 229,
#       'left_child': {'leaf_index': 4,
#        'leaf_value': -0.03534067067189905,
#        'leaf_count': 72},
#       'right_child': {'split_index': 6,
#        'split_feature': 2,
#        'split_gain': 0.5798460245132446,
#        'threshold': 27.500000000000004,
#        'decision_type': '<=',
#        'default_left': True,
#        'missing_type': 'NaN',
#        'internal_value': -0.10897,
#        'internal_count': 157,
#        'left_child': {'split_index': 12,
#         'split_feature': 2,
#         'split_gain': 0.004154520109295845,
#         'threshold': 22.500000000000004,
#         'decision_type': '<=',
#         'default_left': True,
#         'missing_type': 'NaN',
#         'internal_value': 0.149125,
#         'internal_count': 48,
#         'left_child': {'leaf_index': 6,
#          'leaf_value': 0.014291346232367223,
#          'leaf_count': 20},
#         'right_child': {'leaf_index': 13,
#          'leaf_value': 0.010086099948821824,
#          'leaf_count': 28}},
#        'right_child': {'split_index': 7,
#         'split_feature': 2,
#         'split_gain': 0.6662989854812622,
#         'threshold': 33.50000000000001,
#         'decision_type': '<=',
#         'default_left': False,
#         'missing_type': 'NaN',
#         'internal_value': -0.219714,
#         'internal_count': 109,
#         'left_child': {'leaf_index': 7,
#          'leaf_value': -0.04336311249185407,
#          'leaf_count': 33},
#         'right_child': {'split_index': 8,
#          'split_feature': 3,
#          'split_gain': 0.4349310100078583,
#          'threshold': 1.0000000180025095e-35,
#          'decision_type': '<=',
#          'default_left': True,
#          'missing_type': 'None',
#          'internal_value': -0.0762832,
#          'internal_count': 76,
#          'left_child': {'split_index': 9,
#           'split_feature': 2,
#           'split_gain': 0.8702309727668762,
#           'threshold': 44.50000000000001,
#           'decision_type': '<=',
#           'default_left': True,
#           'missing_type': 'NaN',
#           'internal_value': 0.0674257,
#           'internal_count': 54,
#           'left_child': {'leaf_index': 8,
#            'leaf_value': 0.03616991613686712,
#            'leaf_count': 24},
#           'right_child': {'leaf_index': 10,
#            'leaf_value': -0.021059611238850712,
#            'leaf_count': 30}},
#          'right_child': {'leaf_index': 9,
#           'leaf_value': -0.030358515976032507,
#           'leaf_count': 22}}}}}}}},
#   {'tree_index': 59,
#    'num_leaves': 16,
#    'num_cat': 0,
#    'shrinkage': 0.0792807,
#    'tree_structure': {'split_index': 0,
#     'split_feature': 1,
#     'split_gain': 1.2365000247955322,
#     'threshold': 1.0000000180025095e-35,
#     'decision_type': '<=',
#     'default_left': True,
#     'missing_type': 'None',
#     'internal_value': 0,
#     'internal_count': 390,
#     'left_child': {'split_index': 1,
#      'split_feature': 0,
#      'split_gain': 1.222659945487976,
#      'threshold': 2.5000000000000004,
#      'decision_type': '<=',
#      'default_left': True,
#      'missing_type': 'None',
#      'internal_value': 0.200098,
#      'internal_count': 141,
#      'left_child': {'split_index': 9,
#       'split_feature': 6,
#       'split_gain': 0.29654499888420105,
#       'threshold': 1.5000000000000002,
#       'decision_type': '<=',
#       'default_left': True,
#       'missing_type': 'None',
#       'internal_value': 0.600509,
#       'internal_count': 76,
#       'left_child': {'leaf_index': 0,
#        'leaf_value': 0.08452778934643956,
#        'leaf_count': 24},
#       'right_child': {'split_index': 14,
#        'split_feature': 5,
#        'split_gain': 0.03363129869103432,
#        'threshold': 29.412500000000005,
#        'decision_type': '<=',
#        'default_left': True,
#        'missing_type': 'None',
#        'internal_value': 0.483276,
#        'internal_count': 52,
#        'left_child': {'leaf_index': 10,
#         'leaf_value': 0.04283865382971151,
#         'leaf_count': 31},
#        'right_child': {'leaf_index': 15,
#         'leaf_value': 0.02754748462894283,
#         'leaf_count': 21}}},
#      'right_child': {'split_index': 2,
#       'split_feature': 5,
#       'split_gain': 0.9118099808692932,
#       'threshold': 8.093750000000002,
#       'decision_type': '<=',
#       'default_left': True,
#       'missing_type': 'None',
#       'internal_value': 0.0383763,
#       'internal_count': 65,
#       'left_child': {'leaf_index': 2,
#        'leaf_value': 0.0331446164432708,
#        'leaf_count': 20},
#       'right_child': {'split_index': 10,
#        'split_feature': 5,
#        'split_gain': 0.23642300069332123,
#        'threshold': 16.400000000000002,
#        'decision_type': '<=',
#        'default_left': True,
#        'missing_type': 'None',
#        'internal_value': -0.14018,
#        'internal_count': 45,
#        'left_child': {'leaf_index': 3,
#         'leaf_value': -0.00028802650653813623,
#         'leaf_count': 25},
#        'right_child': {'leaf_index': 11,
#         'leaf_value': -0.02611981992926869,
#         'leaf_count': 20}}}},
#     'right_child': {'split_index': 3,
#      'split_feature': 5,
#      'split_gain': 0.6225069761276245,
#      'threshold': 27.135400000000004,
#      'decision_type': '<=',
#      'default_left': True,
#      'missing_type': 'None',
#      'internal_value': -0.126628,
#      'internal_count': 249,
#      'left_child': {'split_index': 4,
#       'split_feature': 5,
#       'split_gain': 1.2416499853134155,
#       'threshold': 7.910400000000001,
#       'decision_type': '<=',
#       'default_left': True,
#       'missing_type': 'None',
#       'internal_value': -0.0221717,
#       'internal_count': 193,
#       'left_child': {'split_index': 6,
#        'split_feature': 5,
#        'split_gain': 0.8225650191307068,
#        'threshold': 7.8646,
#        'decision_type': '<=',
#        'default_left': True,
#        'missing_type': 'None',
#        'internal_value': -0.356717,
#        'internal_count': 85,
#        'left_child': {'split_index': 7,
#         'split_feature': 5,
#         'split_gain': 0.312716007232666,
#         'threshold': 7.745850000000001,
#         'decision_type': '<=',
#         'default_left': True,
#         'missing_type': 'None',
#         'internal_value': -0.199356,
#         'internal_count': 65,
#         'left_child': {'split_index': 8,
#          'split_feature': 6,
#          'split_gain': 0.3278070092201233,
#          'threshold': 1.5000000000000002,
#          'decision_type': '<=',
#          'default_left': True,
#          'missing_type': 'None',
#          'internal_value': -0.337347,
#          'internal_count': 45,
#          'left_child': {'leaf_index': 1,
#           'leaf_value': -0.00669980167750749,
#           'leaf_count': 21},
#          'right_child': {'leaf_index': 9,
#           'leaf_value': -0.05059501243843841,
#           'leaf_count': 24}},
#         'right_child': {'leaf_index': 8,
#          'leaf_value': 0.014942859453482003,
#          'leaf_count': 20}},
#        'right_child': {'leaf_index': 7,
#         'leaf_value': -0.08672870275419745,
#         'leaf_count': 20}},
#       'right_child': {'split_index': 11,
#        'split_feature': 5,
#        'split_gain': 0.1822970062494278,
#        'threshold': 8.093750000000002,
#        'decision_type': '<=',
#        'default_left': True,
#        'missing_type': 'None',
#        'internal_value': 0.166731,
#        'internal_count': 108,
#        'left_child': {'leaf_index': 5,
#         'leaf_value': 0.03620364020405232,
#         'leaf_count': 20},
#        'right_child': {'split_index': 12,
#         'split_feature': 5,
#         'split_gain': 0.25151899456977844,
#         'threshold': 25.5271,
#         'decision_type': '<=',
#         'default_left': True,
#         'missing_type': 'None',
#         'internal_value': 0.116657,
#         'internal_count': 88,
#         'left_child': {'split_index': 13,
#          'split_feature': 5,
#          'split_gain': 0.28193798661231995,
#          'threshold': 14.427100000000001,
#          'decision_type': '<=',
#          'default_left': True,
#          'missing_type': 'None',
#          'internal_value': 0.0151641,
#          'internal_count': 67,
#          'left_child': {'leaf_index': 12,
#           'leaf_value': 0.014865038286101192,
#           'leaf_count': 40},
#          'right_child': {'leaf_index': 14,
#           'leaf_value': -0.016222674101715018,
#           'leaf_count': 27}},
#         'right_child': {'leaf_index': 13,
#          'leaf_value': 0.027597510527763863,
#          'leaf_count': 21}}}},
#      'right_child': {'split_index': 5,
#       'split_feature': 5,
#       'split_gain': 0.8704609870910645,
#       'threshold': 51.931250000000006,
#       'decision_type': '<=',
#       'default_left': True,
#       'missing_type': 'None',
#       'internal_value': -0.325493,
#       'internal_count': 56,
#       'left_child': {'leaf_index': 4,
#        'leaf_value': -0.04998761505636372,
#        'leaf_count': 29},
#       'right_child': {'leaf_index': 6,
#        'leaf_value': -0.0038821033042556134,
#        'leaf_count': 27}}}}}],
#  'pandas_categorical': []}

# %%
train_df[feats].columns
# Out:
# Index(['Pclass', 'Sex', 'Age', 'SibSp', 'Parch', 'Fare', 'Embarked'], dtype='object')

# %%
import seaborn as sns

# %%
sns.countplot(train_df[train_df['Survived'] == 0]['Sex'])

# %%
sns.countplot(train_df[train_df['Survived'] == 1]['Sex'])

# %%
importance = clf.feature_importances_
for i,v in enumerate(importance):
    print('Feature: %0d, Score: %.5f' % (i,v))
# Out:
# Feature: 0, Score: 62.00000
# Feature: 1, Score: 46.00000
# Feature: 2, Score: 284.00000
# Feature: 3, Score: 41.00000
# Feature: 4, Score: 19.00000
# Feature: 5, Score: 316.00000
# Feature: 6, Score: 47.00000

# %%
len(model_json['tree_info'])
# Out:
# 60

# %%
d = model_json['tree_info']

# %%
cols = train_df[feats].columns.values

# %%
cols.values
# Out:
# array(['Pclass', 'Sex', 'Age', 'SibSp', 'Parch', 'Fare', 'Embarked'],
#       dtype=object)

# %%
aa = []
bb = []
cc = []
ee = []

def rec_dict(d):
    global aa
    global bb
    global cc
    global ee
    feature = d.get('split_feature', '')
    threshold = d.get('threshold', '')
    decision_type = d.get('decision_type', '')
    for dd in d:        
        if dd == 'split_gain':
            val = d[dd]
            aa.append(cols[feature])
            bb.append(val)
            cc.append(threshold)
            ee.append(decision_type)
        if dd == 'tree_structure':
            rec_dict(d[dd])
        if dd == 'left_child':
            rec_dict(d[dd])
        if dd == 'right_child':
            rec_dict(d[dd])

# %%
for a in d:
    rec_dict(a)

# %%
d_df = pd.DataFrame({'feature': aa, 'val': bb, 'threshold': cc, 'decision_type': ee})

# %%
sorted_df = d_df.sort_values(by='val', ascending=False)

# %%
sorted_df.head(100)
# Out:
#       feature         val     threshold decision_type
# 0         Sex  103.570999  1.000000e-35            <=
# 15        Sex   86.979897  1.000000e-35            <=
# 27        Sex   73.487900  1.000000e-35            <=
# 69        Sex   56.417599  1.000000e-35            <=
# 82        Sex   48.372299  1.000000e-35            <=
# 92        Sex   41.670399  1.000000e-35            <=
# 102       Sex   39.362999  1.000000e-35            <=
# 42     Pclass   36.787201  2.500000e+00            <=
# 55     Pclass   36.070301  2.500000e+00            <=
# 28     Pclass   35.056999  2.500000e+00            <=
# 129       Sex   33.044601  1.000000e-35            <=
# 157       Sex   30.148399  1.000000e-35            <=
# 143       Sex   28.605400  1.000000e-35            <=
# 172       Sex   26.014000  1.000000e-35            <=
# 182       Sex   22.544701  1.000000e-35            <=
# 83     Pclass   20.967699  2.500000e+00            <=
# 209       Sex   19.309401  1.000000e-35            <=
# 93     Pclass   18.245899  2.500000e+00            <=
# 223       Sex   16.644800  1.000000e-35            <=
# 1        Fare   14.633900  2.552710e+01            <=
# 103    Pclass   14.483300  2.500000e+00            <=
# 252       Sex   14.182200  1.000000e-35            <=
# 6        Fare   12.990200  2.626665e+01            <=
# 33     Pclass   12.964100  1.500000e+00            <=
# 130    Pclass   11.872000  2.500000e+00            <=
# 116    Pclass   11.800900  2.500000e+00            <=
# 43       Fare   10.842400  1.267500e+01            <=
# 144    Pclass   10.618600  2.500000e+00            <=
# 56        Age    9.359760  5.050000e+01            <=
# 70       Fare    9.334830  3.133125e+01            <=
# ..        ...         ...           ...           ...
# 106       Age    4.396890  1.500000e+00            <=
# 86   Embarked    4.377710  1.500000e+00            <=
# 170       Age    4.314950  3.950000e+01            <=
# 264     SibSp    4.276830  2.500000e+00            <=
# 392    Pclass    4.268710  2.500000e+00            <=
# 253    Pclass    4.203220  2.500000e+00            <=
# 187      Fare    4.186950  2.626665e+01            <=
# 386      Fare    4.178130  3.003540e+01            <=
# 133      Fare    4.031130  7.987500e+00            <=
# 215      Fare    3.980210  5.193125e+01            <=
# 335       Age    3.976490  5.300000e+01            <=
# 204       Age    3.944490  9.500000e+00            <=
# 369      Fare    3.930370  2.626665e+01            <=
# 337     SibSp    3.923270  1.500000e+00            <=
# 21        Age    3.872700  5.300000e+01            <=
# 118      Fare    3.841570  1.320835e+01            <=
# 61        Age    3.819180  2.750000e+01            <=
# 7         Age    3.817740  2.050000e+01            <=
# 666      Fare    3.807070  7.762500e+00            <=
# 125       Age    3.799140  2.050000e+01            <=
# 322    Pclass    3.790400  2.500000e+00            <=
# 13        Age    3.724310  2.450000e+01            <=
# 96   Embarked    3.699610  1.500000e+00            <=
# 271     Parch    3.689210  1.000000e-35            <=
# 123      Fare    3.651980  1.937915e+01            <=
# 109       Age    3.632400  2.650000e+01            <=
# 49   Embarked    3.622060  1.000000e-35            <=
# 375       Age    3.598760  5.500000e+00            <=
# 147       Age    3.568940  1.500000e+00            <=
# 415      Fare    3.557160  3.003540e+01            <=
#
# [100 rows x 4 columns]

# %%
sorted_df.groupby(['feature'])['val'].sum()
# Out:
# feature
# 0    338.080626
# 1    725.245604
# 2    408.610107
# 3     68.879976
# 4     33.521064
# 5    448.452418
# 6     72.848031
# Name: val, dtype: float64

# %%
sorted_df.groupby(['feature'])['val'].count()
# Out:
# feature
# 0     62
# 1     46
# 2    284
# 3     41
# 4     19
# 5    316
# 6     47
# Name: val, dtype: int64

# %%
sorted_df.groupby(['feature'])['val'].std()
# Out:
# feature
# 0     8.252984
# 1    24.198095
# 2     1.232313
# 3     1.519379
# 4     1.227721
# 5     1.767070
# 6     1.222206
# Name: val, dtype: float64

# %%
importance
# Out:
# array([ 62,  46, 284,  41,  19, 316,  47])

# %%
lgb.create_tree_digraph(clf.booster_)
